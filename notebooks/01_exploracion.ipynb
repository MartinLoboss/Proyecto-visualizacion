# %%
import pandas as pd

# Carga del dataset desde la carpeta data/raw/
# Ajusta el nombre del archivo si es necesario
path_data = "../data/raw/202607-capitalbikeshare-tripdata.csv"
df = pd.read_csv(path_data)

print("Dataset cargado exitosamente.")

# %%
# Muestra de las primeras 5 filas del dataset
df.dropna().head()

# %%
# Cantidad total de registros (filas) y variables (columnas)
filas, columnas = df.shape
print(f"Total de registros: {filas:,}")
print(f"Total de variables: {columnas}")

# %%
# Información general de los tipos de datos y valores no nulos
df.info()
